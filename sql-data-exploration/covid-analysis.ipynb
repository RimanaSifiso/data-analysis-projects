# %%
import  pandas as pd
from sqlalchemy import create_engine


DB_URI = "mysql+pymysql://root:123456@localhost:3306/covid_data"
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql $DB_URI
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
engine = create_engine(DB_URI)

# load the data from the csv file

df_covid_deaths = pd.read_csv("./data/CovidDeaths.csv", sep=";")
df_covid_vac = pd.read_csv("./data/CovidVaccinations.csv", sep=";")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13352\1848175360.py:5: DtypeWarning: Columns (18,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_covid_deaths = pd.read_csv("./data/CovidDeaths.csv", sep=";")

# %%
df_covid_deaths.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020/02/24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020/02/25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020/02/26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020/02/27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020/02/28          1.0        0.0
#
#   new_cases_smoothed  total_deaths  new_deaths new_deaths_smoothed  ...  \
# 0                NaN           NaN         NaN                 NaN  ...
# 1                NaN           NaN         NaN                 NaN  ...
# 2                NaN           NaN         NaN                 NaN  ...
# 3                NaN           NaN         NaN                 NaN  ...
# 4                NaN           NaN         NaN                 NaN  ...
#
#   gdp_per_capita extreme_poverty cardiovasc_death_rate diabetes_prevalence  \
# ...

# %%
# save as database table 
# df_covid_deaths.to_sql("covid_deaths", engine, if_exists="replace", index=False)
# df_covid_vac.to_sql("covid_vaccinations", engine, if_exists="replace", index=False)
# Out:
# 85171

# %%
# %%sql
# SELECT * FROM covid_deaths LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/covid_data
#    mysql+pymysql://root:***@localhost:3306/sql_store
# 10 rows affected.
# [('AFG', 'Asia', 'Afghanistan', '2020/02/24', 1.0, 1.0, None, None, None, None, '0,026', '0,026', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '8,33', 38928341.0, '54,422', '18,6', '2,581', '1,337', '1803,987', None, '597,029', '9,59', None, None, '37,746', '0,5', '64,83', '0,511'),
#  ('AFG', 'Asia', 'Afghanistan', '2020/02/25', 1.0, 0.0, None, None, None, None, '0,026', '0', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '8,33', 38928341.0, '54,422', '18,6', '2,581', '1,337', '1803,987', None, '597,029', '9,59', None, None, '37,746', '0,5', '64,83', '0,511'),
# ...

# %%
# %%sql
# SELECT * FROM covid_deaths LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/covid_data
#    mysql+pymysql://root:***@localhost:3306/sql_store
# 5 rows affected.
# [('AFG', 'Asia', 'Afghanistan', '2020/02/24', 1.0, 1.0, None, None, None, None, '0,026', '0,026', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '8,33', 38928341.0, '54,422', '18,6', '2,581', '1,337', '1803,987', None, '597,029', '9,59', None, None, '37,746', '0,5', '64,83', '0,511'),
#  ('AFG', 'Asia', 'Afghanistan', '2020/02/25', 1.0, 0.0, None, None, None, None, '0,026', '0', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '8,33', 38928341.0, '54,422', '18,6', '2,581', '1,337', '1803,987', None, '597,029', '9,59', None, None, '37,746', '0,5', '64,83', '0,511'),
# ...

# %%
# %%sql
# SELECT *
# FROM covid_deaths
# ORDER BY 3, 4
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/covid_data
#    mysql+pymysql://root:***@localhost:3306/sql_store
# 10 rows affected.
# [('AFG', 'Asia', 'Afghanistan', '2020/02/24', 1.0, 1.0, None, None, None, None, '0,026', '0,026', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '8,33', 38928341.0, '54,422', '18,6', '2,581', '1,337', '1803,987', None, '597,029', '9,59', None, None, '37,746', '0,5', '64,83', '0,511'),
#  ('AFG', 'Asia', 'Afghanistan', '2020/02/25', 1.0, 0.0, None, None, None, None, '0,026', '0', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '8,33', 38928341.0, '54,422', '18,6', '2,581', '1,337', '1803,987', None, '597,029', '9,59', None, None, '37,746', '0,5', '64,83', '0,511'),
# ...

# %%
# %%sql
# SELECT
#     location,
#     date,
#     total_cases,
#     new_cases,
#     total_deaths,
#     population,
#     (total_deaths/total_cases)*100 AS deaths_percentage
# FROM covid_deaths
# WHERE NOT total_deaths IS NULL AND location LIKE "%south africa%"
# ORDER BY location, date DESC
# LIMIT 20
# Out:
#  * mysql+pymysql://root:***@localhost:3306/covid_data
#    mysql+pymysql://root:***@localhost:3306/sql_store
# 20 rows affected.
# [('South Africa', '2021/04/30', 1581210.0, 1674.0, 54350.0, 59308690.0, 3.4372411001701226),
#  ('South Africa', '2021/04/29', 1579536.0, 1086.0, 54331.0, 59308690.0, 3.4396810202489845),
#  ('South Africa', '2021/04/28', 1578450.0, 1250.0, 54285.0, 59308690.0, 3.4391333269980042),
#  ('South Africa', '2021/04/27', 1577200.0, 880.0, 54237.0, 59308690.0, 3.4388156226223687),
#  ('South Africa', '2021/04/26', 1576320.0, 849.0, 54186.0, 59308690.0, 3.4375000000000004),
#  ('South Africa', '2021/04/25', 1575471.0, 1101.0, 54148.0, 59308690.0, 3.436940445111335),
#  ('South Africa', '2021/04/24', 1574370.0, 1385.0, 54125.0, 59308690.0, 3.437883089743834),
#  ('South Africa', '2021/04/23', 1572985.0, 1637.0, 54066.0, 59308690.0, 3.4371592863250444),
#  ('South Africa', '2021/04/22', 1571348.0, 1413.0, 53995.0, 59308690.0, 3.4362216390003995),
# ...

# %% [markdown]
# **Looking at Total Cases vs Total Deaths**
